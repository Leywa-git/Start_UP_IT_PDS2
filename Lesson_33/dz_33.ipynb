# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
cars = pd.read_excel("cars.xlsx")
cars
# Out:
#          Brand     Model  Price(€)  Consumption(L/100KM)  Max Speed(KM/H)  \
# 0     Mercedes       GLK     15950                  10.2              210
# 1        Lexus        RX     14990                   8.5              200
# 2      Hyundai    Sonata      6500                  10.7              190
# 3   Volkswagen    Passat      7980                   9.0              190
# 4      Renault     Logan      5107                   6.9              162
# 5         Ford    Fusion      5499                   6.2              164
# 6       Nissan   Qashqai      9850                   6.6              179
# 7          Kia      Soul     12450                   5.0              182
# 8       Toyota     Prius     13995                   4.7              180
# 9   Mitsubishi       ASX      9900                   6.1              183
# 10       Honda    Accord      9899                   7.5              212
# 11       Skoda   Octavia      6750                   4.9              196
# 12         BMW        X5     34490                   7.1              222
# 13      Toyota   Corolla      5900                   4.7              174
# 14      Subaru  Forester     11950                   8.4              183
# 15    Mercedes        ML     19945                   8.7              235
# 16     Citroen        C3      7990                   4.3              163
# 17       Acura       MDX     14950                  13.1              224
# 18       Mazda       CX7      8990                  11.5              181
# 19        Opel  Insignia      9400                   5.8              190
#
#     Payload(KG)
# 0           655
# 1           495
# 2           522
# 3           574
# 4           560
# 5           443
# 6           533
# 7           410
# 8           435
# 9           570
# 10          461
# 11          550
# 12          680
# 13          470
# 14          442
# 15          820
# 16          499
# 17          480
# 18          468
# 19          517

# %%
fig, axs = plt.subplots(1, 3, figsize=(14,4))

axs[0].set(title="Consumption to price")
sns.lineplot(data=cars, ax=axs[0], x="Consumption(L/100KM)", y="Price(€)")

axs[1].set(title="Consumption to Max Speed")
sns.scatterplot(data=cars, ax=axs[1], x="Consumption(L/100KM)", y="Max Speed(KM/H)")

axs[2].set(title="Payload to Max Speed")
sns.scatterplot(data=cars, ax=axs[2], x="Payload(KG)", y="Max Speed(KM/H)")
# Out:
# <Axes: title={'center': 'Payload to Max Speed'}, xlabel='Payload(KG)', ylabel='Max Speed(KM/H)'>

# %%
plt.xlabel("Max Speed(KM/H)")
plt.ylabel("Models Total")
plt.hist(cars["Max Speed(KM/H)"], 5, color = "blue", width = 6, align = "mid")
# Out:
# (array([4., 9., 2., 2., 3.]),
#  array([162. , 176.6, 191.2, 205.8, 220.4, 235. ]),
#  <BarContainer object of 5 artists>)

# %%
sns.boxplot(data=cars, x="Max Speed(KM/H)", y="Brand")
# Out:
# <Axes: xlabel='Max Speed(KM/H)', ylabel='Brand'>

# %%
sns.pairplot(cars)
