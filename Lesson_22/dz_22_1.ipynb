# %% [markdown]
# **Students - 37**
# - - -
# **Top grades:**
# - - -
# Mathematics - 15
#
# Physics - 16
#
# Chemistry - 19
# - - -
# Mathematics and Physics - 7
#
# Mathematics and Chemistry - 9
#
# Physics and Chemistry - 6
# - - -
# Mathematics, Physics and Chemistry - 4
# - - -
# **Students with at least 1 top grade - ?**

# %% [markdown]
# Step 1:
# ---
# creating 3 plain sets A for Chemistry, B for Mathematics, C for Physics.

# %% [markdown]
# ![1.png](attachment:1.png)

# %%
A = set([])
B = set([])
C = set([])
print(f"A = {A}")
print(f"B = {B}")
print(f"C = {C}")
# Out:
# A = set()
# B = set()
# C = set()

# %% [markdown]
# Step 2:
# --
# adding the students who got top grade in each subject to each set.
#
# A ∩ B ∩ C = 4

# %% [markdown]
# ![2.png](attachment:2.png)

# %%
A.add("James"), A.add("Patricia"), A.add("David"), A.add("Linda")
B.add("James"), B.add("Patricia"), B.add("David"), B.add("Linda")
C.add("James"), C.add("Patricia"), C.add("David"), C.add("Linda")
print(f"A = {A}")
print(f"B = {B}")
print(f"C = {C}")
# Out:
# A = {'Patricia', 'David', 'James', 'Linda'}
# B = {'Patricia', 'David', 'James', 'Linda'}
# C = {'Patricia', 'David', 'James', 'Linda'}

# %% [markdown]
# Step 3:
# --
# adding the students who got top grade in 2 different subjects to the sets accordingly the name of the subject.
#
# A ∩ B - A ∩ B ∩ C = 9 - 4 = 5
#
# B ∩ C - A ∩ B ∩ C = 7 - 4 = 3
#
# A ∩ C - A ∩ B ∩ C = 6 - 4 = 2

# %% [markdown]
# ![3.png](attachment:3.png)

# %%
A.add("Robert"), A.add("Steve"), A.add("Susan"), A.add("Mark"), A.add("Paul"), A.add("Carol"), A.add("Amanda")
B.add("Robert"), B.add("Steve"), B.add("Susan"), B.add("Mark"), B.add("Paul"), B.add("Brian"), B.add("Ryan"), B.add("Laura")
C.add("Carol"), C.add("Amanda"), C.add("Brian"), C.add("Ryan"), C.add("Laura")
print(f"A = {A}")
print(f"B = {B}")
print(f"C = {C}")
# Out:
# A = {'Patricia', 'David', 'Paul', 'James', 'Linda', 'Mark', 'Susan', 'Carol', 'Amanda', 'Robert', 'Steve'}
# B = {'Patricia', 'David', 'Paul', 'Brian', 'Laura', 'James', 'Linda', 'Mark', 'Ryan', 'Susan', 'Robert', 'Steve'}
# C = {'Patricia', 'David', 'Laura', 'James', 'Linda', 'Ryan', 'Brian', 'Carol', 'Amanda'}

# %% [markdown]
# Step 4:
# --
# adding the students who got top grade in a single subject to the sets accordingly the name of the subject.
#
# A - A ∩ B - A ∩ C + A ∩ B ∩ C = 19 - 9 - 6 + 4 = 8
#
# B - B ∩ A - B ∩ C + A ∩ B ∩ C = 15 - 9 - 7 + 4 = 3
#
# C - C ∩ A - C ∩ B + A ∩ B ∩ C = 16 - 6 - 7 + 4 = 7

# %% [markdown]
# ![4.png](attachment:4.png)

# %%
A.add("Amy"), A.add("Stephen"), A.add("Larry"), A.add("Nicole"), A.add("Scott"), A.add("Debra"), A.add("Rachel"), A.add("Jack")
B.add("Jerry"), B.add("Diane"), B.add("Olivia")
C.add("Peter"), C.add("Kyle"), C.add("Roger"), C.add("Gloria"), C.add("Ann"), C.add("Jean"), C.add("Joe")
print(f"A = {A}")
print(f"B = {B}")
print(f"C = {C}")
# Out:
# A = {'Patricia', 'Paul', 'Larry', 'Stephen', 'Linda', 'Nicole', 'Carol', 'Susan', 'Amanda', 'Steve', 'Amy', 'Debra', 'Rachel', 'David', 'Scott', 'Jack', 'James', 'Mark', 'Robert'}
# B = {'Patricia', 'David', 'Paul', 'Brian', 'Laura', 'James', 'Linda', 'Mark', 'Ryan', 'Diane', 'Jerry', 'Susan', 'Robert', 'Olivia', 'Steve'}
# C = {'Patricia', 'David', 'Kyle', 'Laura', 'Ann', 'James', 'Linda', 'Ryan', 'Joe', 'Roger', 'Jean', 'Gloria', 'Brian', 'Carol', 'Amanda', 'Peter'}

# %% [markdown]
# Step 5:
# --
# counting all the students who got at least 1 top grade.

# %%
A.update(B, C)
solution = len(A)
print(f"{solution} is the number of students who got at least 1 top grade among all of 37 students")
# Out:
# 32 is the number of students who got at least 1 top grade among all of 37 students

# %% [markdown]
# **Students with at least 1 top grade - 32**
