# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Loading the image**

# %%
def load_image(file):
    img = cv2.imread(file, cv2.IMREAD_COLOR)
    return img

# %% [markdown]
# **Showing the image**

# %%
def show_image(file):
    img = load_image(file)
    img_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.axis("off")
    plt.imshow(img_RGB)
    return plt.show()

# %%
a = show_image("DA.jpg")
a

# %% [markdown]
# **Saving the image**

# %%
def save_image(filename, image):
    saved_image = cv2.imwrite(filename, image)
    print(f"saved as {filename}")
    return None

# %% [markdown]
# **Changing the contrast of the image**

# %%
def adjust_contrast(file, contrast, brightness):
    img = load_image(file)
    img_new = cv2.convertScaleAbs(img, alpha=contrast, beta=brightness)
    filename = f"contrast_adjusted_{file}"
    save_image(filename, img_new)
    return show_image(filename)

# %%
adjust_contrast("DA.jpg", 0.3, 1)
# Out:
# saved as contrast_adjusted_DA.jpg

# %% [markdown]
# **Changing the brightness of the image**

# %%
def adjust_brightness(file, brightness):
    img = load_image(file)
    img_new = cv2.convertScaleAbs(img, beta=brightness)
    filename = f"brightness_adjusted_{file}"
    save_image(filename, img_new)
    return show_image(filename)

# %%
adjust_brightness("DA.jpg", 90)
# Out:
# saved as brightness_adjusted_DA.jpg

# %% [markdown]
# **Changing the saturation of the image**

# %%
def adjust_saturation(file, saturation):
    img = load_image(file)
    hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv_img)
    s = cv2.convertScaleAbs(s, alpha=saturation)
    hsv_img = cv2.merge([h, s, v])
    img_new = cv2.cvtColor(hsv_img, cv2.COLOR_HSV2BGR)
    filename = f"saturation_adjusted_{file}"
    save_image(filename, img_new)
    return show_image(filename)

# %%
adjust_saturation("DA.jpg", 20)
# Out:
# saved as saturation_adjusted_DA.jpg

# %% [markdown]
# **Changing the size of the image**

# %%
def resize_image(file, new_width, new_height):
    img = load_image(file)
    img_new = cv2.resize(img, (new_width, new_height))
    filename = f"resized_{new_width}x{new_height}_{file}"
    save_image(filename, img_new)
    return show_image(filename)

# %%
resize_image("DA.jpg", 250, 250)
# Out:
# saved as resized_250x250_DA.jpg

# %% [markdown]
# **Cropping the image**

# %%
def crop_image(file, x1, y1, x2, y2):
    img = load_image(file)
    img_new = img[y1:y2, x1:x2]
    filename = f"cropped_{file}"
    save_image(filename, img_new)
    return show_image(filename)

# %%
crop_image("DA.jpg", 600, 600, 700, 700)
# Out:
# saved as cropped_DA.jpg

# %% [markdown]
# **rotating the image**

# %%
def rotate_image(file, angle):
    img = load_image(file)
    height, width = img.shape[:2]
    rotation_matrix = cv2.getRotationMatrix2D((width/2, height/2), angle, 1)
    img_new = cv2.warpAffine(img, rotation_matrix, (width, height))
    filename = f"rotated_{file}"
    save_image(filename, img_new)
    return show_image(filename)

# %%
rotate_image("DA.jpg", 270)
# Out:
# saved as rotated_DA.jpg
